# %%
import pandas as pd

pd.set_option("max_rows", 120)
pd.set_option("max_colwidth", None)

df = pd.read_csv('lab6.csv')

df[['Username','Feedback to Learner']].head(102)
# Out:
#      Username  \
# 0     kladams
# 1     abdalli
# 2    jamering
# 3    eaarcher
# 4    jbadrina
# 5    stbelche
# 6    vbharath
# 7    sambhosa
# 8      mbobba
# 9    matbower
# 10   jasebrad
# 11   bburriss
# 12   bacarlto
# 13   viccerda
# 14   rchabuks
# 15   weiyuche
# 16   shaychow
# 17   mercrane
# 18   sdagguba
# 19   devdaley
# 20   sedornak
# 21     pelele
# 22    gemesih
# 23   vgabbita
# 24   blgalleg
# 25   hgallina
# 26   pganguru
# 27   gar54782
# 28   dgardene
# 29   lijgeorg
# 30   gib77606
# 31   kgidwani
# 32   thgilmor
# 33   rgoranta
# 34   casgrana
# 35   jargreen
# 36   vgudapat
# 37     sgutta
# 38   ham64459
# 39   rhedderm
# 40   andrholm
# 41   oginikor
# 42   olivejoh
# 43   harrikin
# 44   jaredkin
# 45   ikoregav
# 46    tkuchta
# 47    jaekwon
# 48    trlibre
# 49   jmaddine
# 50   tmalkows
# 51   dmallela
# 52   mitmclau
# 53   jahmelto
# 54   ambemoli
# 55    almonge
# 56   ngu89225
# 57    ynikumb
# 58   tnyowheo
# 59   cohenhen
# 60   matojeda
# ...
